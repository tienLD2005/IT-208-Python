# %%
#Bai 1
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 200)
y = x**2

fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title("Biểu đồ đầu tay của Tien")
ax.set_xlabel("Trục x")
ax.set_ylabel("Trục y")
ax.grid(True, linestyle="--")

plt.show()

# %%
#Bai 2
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 200)
y = x**3

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(x, y, color='red', linewidth=3)
ax.set_title("Đồ thị hàm bậc ba y = x³")
ax.set_xlabel("Giá trị x")
ax.set_ylabel("Giá trị y")
ax.grid(True, linestyle="--", alpha=0.6)

plt.show()

# %%
#bai 3
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 20)
y = 2*x + 3

fig, ax = plt.subplots()
ax.plot(x, y, color='blue', linewidth=3)
ax.set_title("Đường thẳng y = 2x + 3")
ax.set_xlabel("Trục x")
ax.set_ylabel("Trục y")
ax.grid(True)

plt.show()

# %%
#Bai 4
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 200)

fig, ax = plt.subplots()
ax.plot(x, np.sin(x), color='blue')
ax.plot(x, np.cos(x), color='red', linestyle='--')
ax.set_title("So sánh sin(x) và cos(x)")
ax.set_xlabel("Trục x")
ax.set_ylabel("Trục y")
ax.grid(True)
ax.legend(["sin(x)", "cos(x)"])

plt.show()

# %%
#Bai 5
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 200)
y1 = 2*x + 1
y2 = -x + 10

fig, ax = plt.subplots()
ax.plot(x, y1, color='blue', label="Đường 1")
ax.plot(x, y2, color='orange', label="Đường 2")
ax.set_title("Giao điểm của hai đường thẳng")
ax.set_xlabel("Trục x")
ax.set_ylabel("Trục y")
ax.grid(True)
ax.legend(loc="upper left")

plt.show()

# %%
#Bai 6
import numpy as np
import matplotlib.pyplot as plt

years = np.arange(2015, 2025)
population = np.array([92, 93, 94, 95, 96, 97, 98, 99, 100, 101])

fig, ax = plt.subplots()
ax.plot(years, population, color='blue', linestyle='-', marker='o', linewidth=2, label="Dân số")
ax.set_title("Tăng trưởng dân số Việt Nam 2015–2024")
ax.set_xlabel("Năm")
ax.set_ylabel("Dân số (triệu người)")
ax.grid(True)
ax.legend()

plt.show()

# %%
#Bai 7
import matplotlib.pyplot as plt

products = ["Áo", "Quần", "Giày", "Túi", "Mũ", "Tất"]
sales = [150, 120, 200, 90, 65, 80]

fig, ax = plt.subplots()
bars = ax.bar(products, sales, color='green', edgecolor='black')

for bar, value in zip(bars, sales):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
            str(value), ha='center', va='bottom', color='white', fontweight='bold')

ax.set_title("Doanh số bán hàng tháng 10/2025")
ax.set_xlabel("Sản phẩm")
ax.set_ylabel("Doanh số (triệu)")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

months = np.arange(1, 13)
temp = [20, 22, 25, 28, 30, 32, 31, 30, 28, 26, 23, 21]
rain = [10, 15, 30, 120, 200, 250, 280, 220, 150, 80, 30, 15]

fig, ax = plt.subplots()
ax.plot(months, temp, color='red', label="Nhiệt độ")
ax.scatter(months, rain, s=80, color='blue', label="Lượng mưa")
ax.set_title("Nhiệt độ và lượng mưa Hà Nội 2025")
ax.set_xlabel("Tháng")
ax.set_ylabel("Giá trị")
ax.grid(True)
ax.legend()

plt.show()
